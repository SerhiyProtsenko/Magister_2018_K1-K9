# %% [markdown]
# ## Спроба пошуку кореляції між коеф. К1-К9 та виділеним бюджетним місцям в магістратуру

# %% [markdown]
# Згідно наказу МОН №445  “Про затвердження Критеріїв конкурсного відбору виконавців державного замовлення на підготовку магістрів у закладах вищої освіти, які знаходяться у сфері управління МОН”  див. http://zakon3.rada.gov.ua/laws/show/z0625-18 . Запроваджується система згідно якої кожен ЗВО (заклад вищої освіти) повинен отримати ту кількість держбюджетних місць в магістратуру в 2018 році на яку він заслуговує згідно критеріїв, які підтверджують якість наукової роботи, диверсифікацію доходів, якість кадрового забезпечення тощо (див. детально наказ).
#
# Кожен ЗВО повинен був надати необхідну інформацію для розрахунку критеріїв К1-К9 за кожного спеціальністю, надати обсяги випуску бакалаврів в 2018 році тощо.
#
# Після перевірки значень коефіцієнтів К1-К9, утворена комісія в МОН знаходить добуток коефіцієнтів К1-К9 та потім підраховує конкурсний бал, як добуток обсягу випуску бакалавра на добуток коефіцієнтів К1-К9 (див. детально наказ п.6).
#
# Конкурсний бал (розраховується для кожної окремої спеціальності ) = К1*К2*К3*К4*К5*К6*К7*К8*К9*”обсяг випуску бакалаврів за спеціальністю”
#
# І згідно пукту 6 зазначеного наказу : “визначення обсягу державного замовлення проводить Комісія окремо за кожною конкурсною позицією пропорційно конкурсному балу”. В результаті ЗВО, який мав гарні показники К1-К9 повинен був розраховувати на максимальні обсяги держбюджетних місць під всіх або практично під всіх випускників бакалавратури.
#
# Ідея наказу взагалі гарна. Оцінити університети і окремі спеціальності в цих університетах за критеріями і пропорційно ним і обсягу випуску бакалаврів розподіляти держбюджетні місця і надавати держбюджетні місця тільки тим університетам, які на це заслуговують і можуть дійсно забезпечити якісну освіту.
#
# Давайте спробуємо перевірити цей добрий намір. Забігаючи наперед, я побачив, що обсяг  виділених держбюджетних місць в магістратуру в 2018 році дуже слабо або взагалі не корелює з коефіцієнтами К1-К9 та їх добутком і як в минулі роки розподіл держбюджетних місць скоріш за все відбувався в “ручному режимі”   (дивлячись тільки на обсяги випуску бакалаврів), а можливо я щось не врахував і тому прошу вивчити мої розрахунки, щоб ми всі разом зрозуміли де істина (я вже змарнував весь вихідний на це).

# %% [markdown]
# Одна з проблем, яку ми повинні вирішити це те, що необхідна нам інформація знаходиться в трьох різних pdf файлах, яку ми повинні зібрати до купи.
# Користуватися ми будемо трьома файлами pdf, які розміщені на сайті МОН і є офіційними (https://mon.gov.ua/storage/app/media/vishcha-osvita/vstup-2018/dergavne-zamovlenna/komisia/2-konkursna-komisiya-mon-z-vidboru-vikonavtsiv-dz-130718.rar та https://mon.gov.ua/storage/app/media/vishcha-osvita/vstup-2018/komisiya-mon-z-vidboru-vikonavtsiv-dz-200718.rar )
#
# 1. Перший файл: Критерії К-5_К-9.pdf - тут є необхідна для нас інформація про обсяги випуску бакалаврів. В таблиці більш ніж 3000 записів (по всім ЗВО та спеціальностям в державі). Pdf сформований кривувато і тому пришлось довго чистити мусор.
# 2. Другий файл: Коофіцієнти (Наказ 445).pdf - містить в собі інформацію по значенням розрахованих коефіцієнтів К1-К9. В таблиці більш ніж 3000 записів (по всім ЗВО та спеціальностям в державі). Pdf сформований краще, з ним було менше проблем.
# 3. Третій файл: Обсяг Магістратура.pdf - містить в собі саме головне: обсяги виділених держбюджетних місць в магістратуру. В таблиці більш ніж 3000 записів (по всім ЗВО та спеціальностям в державі). Pdf сформований краще, з ним було менше проблем.
#
# Перша задача, розпарсити ці три файли та звести докупи. Потім нагенерити додаткових фітч та подивитися на це все очами Data Scientist’a ;)

# %%
# Зробимо імпорт необхідних модулів
from tabula import read_pdf
import tabula
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_rows", 5000)

# %%
#Зчитаємо спочатку файл Обсяг Магістратура.pdf та зробимо парсінг за допомогою бібліотекі tabula
df_budj=read_pdf('Обсяг Магістратура.pdf', pages='all', lattice=True)

# %%
#Видалемо перший непотрібний рядок
df_budj.drop(0, axis=0,inplace=True)

# %%
#Дамо назви стовпчикам 
df_budj.columns=['код ЗВО', 'Назва ЗВО','Код спец.','Код. спеціал', 'Назва спец.',
               'Обсяг державного замовлення, денна', 'Обсяг державного замовлення, заочна']

# %%
#Приберемо сміття в стовпчику 'Код спец.'
df_budj['Код спец.'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
# Перетворимо текстові значення в числа в зазначених стовчиках
df_budj['код ЗВО']=df_budj['код ЗВО'].map(lambda x: int(x))
df_budj['Код спец.']=df_budj['Код спец.'].map(lambda x: int(x))
df_budj['Обсяг державного замовлення, денна']=df_budj['Обсяг державного замовлення, денна'].map(lambda x: int(x))
df_budj['Обсяг державного замовлення, заочна']=df_budj['Обсяг державного замовлення, заочна'].map(lambda x: int(x))

# %%
#В випадку коли не вказаний код спеціалізації замінемо її на 11111
df_budj['Код. спеціал'].fillna(11111, inplace=True)

# %%
# Перетворимо текстові значення в числа
df_budj['Код. спеціал']=df_budj['Код. спеціал'].map(lambda x: int(x))

# %%
#Подивимося на розмір нашої таблиці
df_budj.shape
# Out:
# (6626, 7)

# %%
#Подивимося (перші п'ять рядків), як виглядає файл Обсяг Магістратура.pdf
df_budj.head()
# Out:
#    код ЗВО                                          Назва ЗВО  Код спец.  \
# 1      101  Черкаський нацiональний унiверситет iм. Богдан...         11
# 2      101  Черкаський нацiональний унiверситет iм. Богдан...         11
# 3      101  Черкаський нацiональний унiверситет iм. Богдан...         12
# 4      101  Черкаський нацiональний унiверситет iм. Богдан...         12
# 5      101  Черкаський нацiональний унiверситетК iмод. Б с...         13
#
#    Код. спеціал                                 Назва спец.  \
# 1         11111                  Освітні, педагогічні науки
# 2         11111  у т.ч. за освітньо-професійними програмами
# 3         11111                            Дошкільна освіта
# 4         11111  у т.ч. за освітньо-професійними програмами
# 5         11111                            Початкова освіта
#
#    Обсяг державного замовлення, денна  Обсяг державного замовлення, заочна
# 1                                   9                                    4
# 2                                   9                                    4
# 3                                  19                                   11
# 4                                  19                                   11
# 5                                  12                                   13

# %%
#Зчитаємо файл Коофіцієнти (Наказ 445).pdf та зробимо парсінг за допомогою бібліотекі tabula
df=read_pdf('Коофіцієнти (Наказ 445).pdf', pages='all', lattice=True)

# %%
#У зв'язку з тим, що в файлах МОН містяться помилки. 14 строк ми видалемо, оскільки в інших файлах їх не існує
df.drop(index=list(range(609,623)),axis=0, inplace=True)

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.drop(index=739,inplace=True,axis=0)

# %%
df.reset_index(inplace=True, drop=True)

# %%
# Подивимося на розмір нашої таблиці файл Коофіцієнти (Наказ 445).pdf
df.shape
# Out:
# (3014, 15)

# %%
#Подивимося (перші п'ять рядків), як виглядає файл Коофіцієнти (Наказ 445).pdf
df.head()
# Out:
#     рік  Код\rВНЗ                                          назва ВНЗ  \
# 0  2018       101  Черкаський нацiональний унiверситет iм. Богдан...
# 1  2018       101  Черкаський нацiональний унiверситет iм. Богдан...
# 2  2018       101  Черкаський нацiональний унiверситет iм. Богдан...
# 3  2018       101  Черкаський нацiональний унiверситет iм. Богдан...
# 4  2018       101  Черкаський нацiональний унiверситет iм. Богдан...
#
#    Unnamed: 3  Unnamed: 4                                назва спеціальності  \
# 0          11         NaN                         Освітні, педагогічні науки
# 1          12         NaN                                   Дошкільна освіта
# 2          13         NaN                                   Початкова освіта
# 3          14         1.0      Середня освіта (українська мова і література)
# 4          14         2.0  Середня освіта (мова і література (із зазначен...
#
#      К1    К2 К3    К4   К5   К6    К7    К8    К9
# 0  1,07  1,07  1  1,02  1,1  1,1   1,2     1     1
# 1  1,07  1,07  1  1,02  1,1    1   1,2  1,01     1
# 2  1,07  1,07  1  1,02  1,1    1  1,09     1     1
# 3  1,07  1,07  1  1,02  1,1    1  1,03     1     1
# 4  1,07  1,07  1  1,02  1,1    1  1,08     1  1,08

# %%
#Зчитаємо останній файл Критерії К-5_К-9.pdf та зробимо парсінг за допомогою бібліотекі tabula
df_old=read_pdf('Критерії К-5_К-9.pdf', pages='all', lattice=True)

# %%
#У зв'язку з тим, що в файлах МОН містяться помилки. 14 строк ми видалемо, оскільки в інших файлах їх не існує
df_old.drop(index=list(range(609,613)),axis=0, inplace=True)

# %%
df_old.reset_index(inplace=True,drop=True )

# %%
# Подивимося на розмір нашої таблиці файл Критерії К-5_К-9.pdf
df_old.shape
# Out:
# (3014, 13)

# %%
#Подивимося (перші п'ять рядків), як виглядає файл Критерії К-5_К-9.pdf
df_old.head()
# Out:
#     рік  Код\rВНЗ                                    назва ВНЗ Unnamed: 3  \
# 0  2018       101  Черкаський нацiональний унiверситет iм. Бог   0а1н1а Х
# 1  2018       101  Черкаський нацiональний унiверситет iм. Бог   0а1н2а Х
# 2  2018       101  Черкаський нацiональний унiверситет iм. Бог   0а1н3а Х
# 3  2018       101  Черкаський нацiональний унiверситет iм. Бог   0а1н4а Х
# 4  2018       101  Черкаський нацiональний унiверситет iм. Бог   0а1н4а Х
#
#   Unnamed: 4                                назва спеціальності  \
# 0        ель                  Оицсвькітонгіо, педагогічні науки
# 1        ель                            Диоцшьккоілгоьна освіта
# 2        ель                             Пицочьакотгкова освіта
# 3      0е1ль  Сицерькеодгноя освіта (українська мова і літер...
# 4      0е2ль  Сицерькеодгноя освіта (мова і література (із з...
#
#   Випуск\rбакалавра\r(денна) Випуск\rбакалавра\r(заочна)  К-5  К-6   К-7  \
# 0                          0                           0  1,1  1,1   1,2
# 1                         27                          10  1,1    1   1,2
# 2                         17                          14  1,1    1  1,11
# 3                         30                           6  1,1    1  1,03
# 4                         52                           7  1,1    1  1,08
#
#     К-8    k9
# 0     1     1
# 1  1,01     1
# 2     1     1
# 3     1     1
# 4     1  1,08

# %% [markdown]
# #### Зробимо деякі перетворення: нові назви стовпчиків, перетворимо рядки в числа тощо

# %%
df_old.columns=['рік', 'код ЗВО', 'Назва ЗВО','Код спец.','Код. спеціал', 'Назва спец.',
                                'Випуск бак., денна','Випуск бак., заоч','K-5','K-6','K-7','K-8','K-9']

# %%
df_old['Випуск бак., денна'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
df['Випуск бак., денна']=df_old['Випуск бак., денна']

# %%
df.columns=['рік', 'код ЗВО', 'Назва ЗВО','Код спец.','Код. спеціал', 'Назва спец.',
                                'K1','K2','K3','K4','K5','K6','K7','K8','K9', 'Випуск бак., денна']

# %%
df['код ЗВО']=df['код ЗВО'].map(lambda x: int(x))

# %%
df['Код спец.']=df['Код спец.'].map(lambda x: int(x))

# %%
df['Випуск бак., денна']=df['Випуск бак., денна'].map(lambda x: int(x))

# %%
df['Код. спеціал'].fillna(11111, inplace=True)

# %%
df['Код. спеціал']=df['Код. спеціал'].map(lambda x: int(x))

# %%
# Перетворимо рядки коеф. К1-К9 в числа з плаваючою комою
df['K1']=[float(x.replace(',','.')) for x in df['K1']]
df['K2']=[float(x.replace(',','.')) for x in df['K2']]
df['K3']=[float(x.replace(',','.')) for x in df['K3']]
df['K4']=[float(x.replace(',','.')) for x in df['K4']]
df['K5']=[float(x.replace(',','.')) for x in df['K5']]
df['K6']=[float(x.replace(',','.')) for x in df['K6']]
df['K7']=[float(x.replace(',','.')) for x in df['K7']]
df['K8']=[float(x.replace(',','.')) for x in df['K8']]
df['K9']=[float(x.replace(',','.')) for x in df['K9']]

# %%
# Згідно Наказу МОН, якщо випуск бакалаврів менше 5, то встановлювати значення випуску = 5
# Для цього створемо новий рядок та дамо назву "Випуск бак. min 5, денна"
df['Випуск бак. min 5, денна']=df['Випуск бак., денна'].map(lambda x: 5 if x<5 else x)

# %%
df.head()
# Out:
#     рік  код ЗВО                                          Назва ЗВО  \
# 0  2018      101  Черкаський нацiональний унiверситет iм. Богдан...
# 1  2018      101  Черкаський нацiональний унiверситет iм. Богдан...
# 2  2018      101  Черкаський нацiональний унiверситет iм. Богдан...
# 3  2018      101  Черкаський нацiональний унiверситет iм. Богдан...
# 4  2018      101  Черкаський нацiональний унiверситет iм. Богдан...
#
#    Код спец.  Код. спеціал                                        Назва спец.  \
# 0         11         11111                         Освітні, педагогічні науки
# 1         12         11111                                   Дошкільна освіта
# 2         13         11111                                   Початкова освіта
# 3         14             1      Середня освіта (українська мова і література)
# 4         14             2  Середня освіта (мова і література (із зазначен...
#
#      K1    K2   K3    K4   K5   K6    K7    K8    K9  Випуск бак., денна  \
# 0  1.07  1.07  1.0  1.02  1.1  1.1  1.20  1.00  1.00                   0
# 1  1.07  1.07  1.0  1.02  1.1  1.0  1.20  1.01  1.00                  27
# 2  1.07  1.07  1.0  1.02  1.1  1.0  1.09  1.00  1.00                  17
# 3  1.07  1.07  1.0  1.02  1.1  1.0  1.03  1.00  1.00                  30
# 4  1.07  1.07  1.0  1.02  1.1  1.0  1.08  1.00  1.08                  52
#
#    Випуск бак. min 5, денна
# 0                         5
# 1                        27
# 2                        17
# 3                        30
# 4                        52

# %% [markdown]
# ### Почнемо переміщення даних з однієї табліці до іншої

# %%
arr_opp=[]
arr_onp=[]

for index,row in df.iterrows():
    
    arr_opp.append(df_budj['Обсяг державного замовлення, денна'].loc[(df_budj['код ЗВО']==row['код ЗВО']) & (df_budj['Код спец.']==row['Код спец.']) & (df_budj['Код. спеціал']==row['Код. спеціал']) & (df_budj['Назва спец.']=='у т.ч. за освітньо-професійними програмами')])
    arr_onp.append(df_budj['Обсяг державного замовлення, денна'].loc[(df_budj['код ЗВО']==row['код ЗВО']) & (df_budj['Код спец.']==row['Код спец.']) & (df_budj['Код. спеціал']==row['Код. спеціал']) & (df_budj['Назва спец.']=='у т.ч. за освітньо-науковими програмами') ])

# %%
opp=[]
onp=[]
for i,_ in enumerate(arr_opp):
    if len(arr_opp[i].values)==0:
        opp.append(0)
    else:
        opp.append(arr_opp[i].values[0])
    if len(arr_onp[i].values)==0:
        onp.append(0)
    else:
        onp.append(arr_onp[i].values[0])

# %%
# Створимо нові окремі стовчики: 'Обсяг державного замовлення ОПП, денна'
# та 'Обсяг державного замовлення ОНП, денна'
df['Обсяг державного замовлення ОПП, денна']=opp
df['Обсяг державного замовлення ОНП, денна']=onp

# %%
# Створимо новий стовчик: 'Обсяг державного замовлення Всього, денна'
df['Обсяг державного замовлення Всього, денна']=np.array(opp)+np.array(onp)

# %%
# Створимо новий стовчик: 'Mult K1-K9' якій дорівнює добутку коеф. К1-К9
df.insert(loc=15, column='Mult K1-K9', value=(df['K1']*df['K2']*df['K3']*df['K4']*df['K5']*
                                            df['K6']*df['K7']*df['K8']*df['K9']))

# %%
# Створимо новий стовчик: 'Конкурсний бал' якій дорівнює добутку коеф. К1-К9 та Випуск бак.
df.insert(loc=18, column='Конкурсний бал', value=(df['Mult K1-K9']*df['Випуск бак. min 5, денна']))

# %% [markdown]
# ### Створимо новий дуже цікавий стовчик:'% наданого державного замовлення від випуску бак., денна' Подивимося на скільки % МОН задовольнив пропозиції випуску ЗВО

# %%
# Створимо новий дуже цікавий стовчик:'% наданого державного замовлення від випуску бак., денна'
df['% наданого державного замовлення від випуску бак., денна']=((df['Обсяг державного замовлення Всього, денна']/
                                                                df['Випуск бак. min 5, денна'])*100)

# %% [markdown]
# ### Давайте подивимося, що вийшло. Зробимо сортування (від більшого до меншого) нашої великої таблиці по значенню добутку коефіцієнтів К1-К9 (стовпчик Mult K1-K9). Якщо переглядати таблицю в першу чергу останній стовпчик (% наданого державного замовлення від випуску бак., денна) то вже видно, що величини коефіцієнтів К1-К9 слабо корелюють з наданим бюджетом. Фактично таблиця, що вийшла, це такий собі рейтинг спеціальностей за показниками К1-К9, він доволі цікавий, в ТОПі цікаві університети та спеціальності.

# %%
df.sort_values('Mult K1-K9', axis=0, ascending=False, inplace=False)[:10]
# Out:
#        рік  код ЗВО                                          Назва ЗВО  \
# 1630  2018      307  Київський нацiональний унiверситет технологiй ...
# 134   2018      109  Житомирський державний унiверситет ім. Івана Ф...
# 2323  2018       61  Чернівецький нацiональний унiверситет iм. Юрія...
# 2959  2018       97   Національний унiверситет "Львiвська полiтехнiка"
# 2320  2018       61  Чернівецький нацiональний унiверситет iм. Юрія...
# 615   2018      168                     Сумський державний унiверситет
# 2684  2018       84  Пiвденноукраїнський національний педагогiчний ...
# 2399  2018       62  Харківський національний унiверситет iм. В.Н.К...
# 2400  2018       62  Харківський національний унiверситет iм. В.Н.К...
# 2386  2018       62  Харківський національний унiверситет iм. В.Н.К...
#
#       Код спец.  Код. спеціал  \
# 1630         22         11111
# 134          14             6
# 2323         14            13
# 2959         22         11111
# 2320         14             8
# 615          73         11111
# 2684         14             9
# 2399         72         11111
# 2400         73         11111
# 2386         35            41
#
#                                             Назва спец.    K1    K2   K3  \
# 1630                                             Дизайн  1.11  1.07  1.0
# 134                              Середня освіта (хімія)  1.06  1.07  1.0
# 2323                 Середня освіта (музичне мистецтво)  1.13  1.07  1.0
# 2959                                             Дизайн  1.17  1.07  1.0
# 2320                            Середня освіта (фізика)  1.13  1.07  1.0
# 615                                          Менеджмент  1.25  1.07  1.1
# 2684                       Середня освіта (інформатика)  1.05  1.03  1.0
# 2399          Фінанси, банківська справа та страхування  1.27  1.07  1.1
# 2400                                         Менеджмент  1.27  1.07  1.1
# 2386  Філологія (германські мови та літератури (пере...  1.27  1.07  1.1
#
#         K4                            ...                               K8  \
# 1630  1.00                            ...                             1.03
# 134   1.04                            ...                             1.00
# 2323  1.02                            ...                             1.00
# 2959  1.02                            ...                             1.00
# 2320  1.02                            ...                             1.00
# 615   1.04                            ...                             1.07
# 2684  1.02                            ...                             1.07
# 2399  1.02                            ...                             1.10
# 2400  1.02                            ...                             1.08
# 2386  1.02                            ...                             1.07
#
#         K9  Mult K1-K9  Випуск бак., денна  Випуск бак. min 5, денна  \
# 1630  1.63    2.871203                  79                        79
# 134   2.00    2.830963                  10                        10
# 2323  2.00    2.713220                   8                         8
# 2959  1.41    2.412287                  31                        31
# 2320  1.75    2.374068                  13                        13
# 615   1.00    2.357414                  10                        10
# 2684  1.50    2.337091                  15                        15
# 2399  1.00    2.324536                  28                        28
# 2400  1.00    2.282272                  22                        22
# 2386  1.00    2.261140                  61                        61
#
#       Конкурсний бал  Обсяг державного замовлення ОПП, денна  \
# 1630      226.825046                                      60
# 134        28.309632                                      10
# 2323       21.705763                                       2
# 2959       74.780883                                      10
# 2320       30.862882                                      15
# 615        23.574144                                       8
# 2684       35.056368                                       5
# 2399       65.087007                                       7
# 2400       50.209977                                      17
# 2386      137.929512                                      36
#
#       Обсяг державного замовлення ОНП, денна  \
# 1630                                       0
# 134                                        0
# 2323                                       0
# 2959                                      10
# 2320                                       0
# 615                                        0
# 2684                                       0
# 2399                                       0
# 2400                                       0
# 2386                                       0
#
#       Обсяг державного замовлення Всього, денна  \
# 1630                                         60
# 134                                          10
# 2323                                          2
# 2959                                         20
# 2320                                         15
# 615                                           8
# 2684                                          5
# 2399                                          7
# 2400                                         17
# 2386                                         36
#
#       % наданого державного замовлення від випуску бак., денна
# 1630                                          75.949367
# 134                                          100.000000
# 2323                                          25.000000
# 2959                                          64.516129
# 2320                                         115.384615
# 615                                           80.000000
# 2684                                          33.333333
# 2399                                          25.000000
# 2400                                          77.272727
# 2386                                          59.016393
#
# [10 rows x 23 columns]

# %% [markdown]
# ### А тепер зробимо сортування (від більшого до меншого) нашої великої таблиці по 'Коду спеціальності' а потім в рамках однієї спеціальності по значенню добутку коефіцієнтів К1-К9 (стовпчик Mult K1-K9). Тепер ми можемо бачити, як розподіляється бюджет серед університетів по окремо взятим спеціальностям. Якщо переглядати таблицю в першу чергу останній стовпчик (% наданого державного замовлення від випуску бак., денна) то вже видно, що величини коефіцієнтів К1-К9 слабо корелюють з наданим бюджетом.

# %%
df.sort_values(['Код спец.','Mult K1-K9'], axis=0, ascending=False, inplace=False)[:10]
# Out:
#        рік  код ЗВО                                          Назва ЗВО  \
# 1307  2018      246  Донецький нацiональний унiверситет ім. Василя ...
# 2061  2018       41  Київський національний університет ім. Тараса ...
# 2419  2018       62  Харківський національний унiверситет iм. В.Н.К...
# 634   2018      168                     Сумський державний унiверситет
# 1569  2018      282  Львівський нацiональний унiверситет імені Іван...
# 1496  2018       28  Одеський нацiональний унiверситет ім. І.І.Мечн...
# 3013  2018       97   Національний унiверситет "Львiвська полiтехнiка"
# 1112  2018       21  Схiдноукраїнський нацiональний унiверситет іме...
# 206   2018      111  Дніпровський нацiональний унiверситет ім. Олес...
# 1057  2018      207              Ужгородський нацiональний унiверситет
#
#       Код спец.  Код. спеціал                      Назва спец.    K1    K2  \
# 1307        292         11111  Міжнародні економічні відносини  1.07  1.07
# 2061        292         11111  Міжнародні економічні відносини  1.19  1.03
# 2419        292         11111  Міжнародні економічні відносини  1.27  1.07
# 634         292         11111  Міжнародні економічні відносини  1.25  1.07
# 1569        292         11111  Міжнародні економічні відносини  1.15  1.07
# 1496        292         11111  Міжнародні економічні відносини  1.21  1.07
# 3013        292         11111  Міжнародні економічні відносини  1.17  1.07
# 1112        292         11111  Міжнародні економічні відносини  1.05  1.07
# 206         292         11111  Міжнародні економічні відносини  1.10  1.07
# 1057        292         11111  Міжнародні економічні відносини  1.11  1.07
#
#        K3    K4                            ...                             \
# 1307  1.1  1.10                            ...
# 2061  1.1  1.00                            ...
# 2419  1.1  1.02                            ...
# 634   1.1  1.04                            ...
# 1569  1.1  1.02                            ...
# 1496  1.0  1.02                            ...
# 3013  1.0  1.02                            ...
# 1112  1.0  1.10                            ...
# 206   1.0  1.02                            ...
# 1057  1.0  1.02                            ...
#
#         K8   K9  Mult K1-K9  Випуск бак., денна  Випуск бак. min 5, денна  \
# 1307  1.10  1.0    2.212647                   3                         5
# 2061  1.06  1.0    2.075149                  56                        56
# 2419  1.05  1.0    1.960006                  16                        16
# 634   1.04  1.0    1.872965                  11                        11
# 1569  1.03  1.0    1.855975                  23                        23
# 1496  1.10  1.0    1.821627                   3                         5
# 3013  1.02  1.0    1.805233                  12                        12
# 1112  1.10  1.0    1.794454                   5                         5
# 206   1.10  1.0    1.789669                  12                        12
# 1057  1.01  1.0    1.695866                  11                        11
#
#       Конкурсний бал  Обсяг державного замовлення ОПП, денна  \
# 1307       11.063237                                       6
# 2061      116.208362                                      36
# 2419       31.360103                                      16
# 634        20.602613                                      11
# 1569       42.687426                                      21
# 1496        9.108137                                       5
# 3013       21.662793                                       2
# 1112        8.972271                                       3
# 206        21.476028                                      11
# 1057       18.654526                                      10
#
#       Обсяг державного замовлення ОНП, денна  \
# 1307                                       0
# 2061                                       0
# 2419                                       0
# 634                                        0
# 1569                                       0
# 1496                                       0
# 3013                                      10
# 1112                                       0
# 206                                        0
# 1057                                       0
#
#       Обсяг державного замовлення Всього, денна  \
# 1307                                          6
# 2061                                         36
# 2419                                         16
# 634                                          11
# 1569                                         21
# 1496                                          5
# 3013                                         12
# 1112                                          3
# 206                                          11
# 1057                                         10
#
#       % наданого державного замовлення від випуску бак., денна
# 1307                                         120.000000
# 2061                                          64.285714
# 2419                                         100.000000
# 634                                          100.000000
# 1569                                          91.304348
# 1496                                         100.000000
# 3013                                         100.000000
# 1112                                          60.000000
# 206                                           91.666667
# 1057                                          90.909091
#
# [10 rows x 23 columns]

# %%
#Давайте збережемо цб таблицю в форматі Exсel для 'ліриків'
file=df.sort_values(['Код спец.','Mult K1-K9'], axis=0, ascending=False, inplace=False)
file.to_excel('Mag2018_K1_k9.xlsx')

# %% [markdown]
# ### Давайте спробуємо розібратися в природі наших показників. Спочатку віалізуємо гістограму Добуток коеф. К1-К9 по всім значенням в таблиці. Гарний знак, що ми бачимо розподіл Гауса (або нормальний розподіл) з  правим хвостом.

# %%
plt.figure(figsize=(10,7))
plt.title('Розподіл добутку коеф. К1-К9 по всім записам в таблиці')
plt.xlabel('Добуток коеф. К1-К9')
plt.ylabel('Частоти розподілу')
plt.xlim(1,3)
plt.hist(df['Mult K1-K9'], bins=100)
#plt.savefig("hist.png")
plt.show()

# %% [markdown]
# ### Подивимося на кількісний розподіл випуску бакалаврів. Особливих претензій немає. Природа розподілу зрозуміла.

# %%
plt.figure(figsize=(10,7))
plt.title('Випуск бакалаврів, денна по всім записам в таблиці')
plt.xlabel('Випуск бакалаврів, денна')
plt.ylabel('Частоти розподілу')
plt.xlim(0,150)
plt.hist(df['Випуск бак. min 5, денна'], bins=200)
#plt.savefig("hist.png")
plt.show()

# %% [markdown]
# ### Подивимося на 'Конкурсний бал', згідно наказа це добуток всіх коефіцієнтів на обсяг випуску бакалаврів. Особливих претензій немає. Природа розподілу зрозуміла.

# %%
plt.figure(figsize=(10,7))
plt.title('Конкурсний бал, денна по всім записам в таблиці')
plt.xlabel('Конкурсний бал, денна')
plt.ylabel('Частоти розподілу')
plt.xlim(0,400)
plt.hist(df['Конкурсний бал'], bins=200)
#plt.savefig("hist.png")
plt.show()

# %% [markdown]
# ### Подивимося на розподіл надоного державного замовлення на ОС магістр, згідно наказа кількість місць повинна бути пропорційна 'Конкурсному балу' (див попередній рисунок). Що ми бачимо? Розподіл став гірше, бачимо незрозумілі максимуми.

# %%
plt.figure(figsize=(10,7))
plt.title('Надане державне замовлення, денна по всім записам в таблиці')
plt.xlabel('Надане державне замовлення, денна')
plt.ylabel('Частоти розподілу')
plt.xlim(0,150)
plt.hist(df['Обсяг державного замовлення Всього, денна'], bins=200)
#plt.savefig("hist.png")
plt.show()

# %% [markdown]
# ### Подивимося на дуже цікавий показник - "відсоток наданого державного замовлення за ОС магістр від випуску бакалавра". Що ми бачимо? Бачимо взагалі незрозумілі максимуми в 50%, 60%, 100%.(деталі нижче). Іншими словами комісія МОН, наприклад більше ніж в 200 випадках встановила значення держбюджету рівне 60% від випуску бакалавра, більше 150 разів встановила значення держбюджету рівне 50% та 100% від випуску бакалавра. Взагалі ця гістограма красномовно свідчить, що дуже часто коефіцієнти нихто не враховував, а користувалися цілими числами. (деталі нижче)

# %%
plt.figure(figsize=(10,7))
plt.title('Розподіл % наданого державного замовлення від випуску бак., денна по всім записам в таблиці')
plt.xlabel('% наданого державного замовлення від випуску бак., денна')
plt.ylabel('Частоти розподілу')
plt.xlim(0,201)
plt.hist(df['% наданого державного замовлення від випуску бак., денна'], bins=1000)
#plt.savefig("hist.png")
plt.show()

# %% [markdown]
# ### А давайте порахуємо скільки разів в усій таблиці (3014 записів) зустрічається різні значення показника: "відсоток наданого державного замовлення від випуску бак., денна'". Що ми бачимо? Комісія МОН: 203 раза встановлювало обсяг магістрів на рівні 60%  випуску бакалавра; 188 разів встановлювало обсяг магістрів на рівні 100%  випуску бакалавра, 169 разів встановлювало обсяг магістрів на рівні 50%  випуску бакалавра і т.і. Також популярні цифри: 40%, 80%, 66.667%, 140%, 200% тощо. Зверніть увагу, що переважна кількість цифр цілі! Іншими словами, якщо комісія МОН все ж таки користувалася добутком коефіцієнтів К1-К9 то яким чином вийшли такі красиві цілі числа?

# %%
df['% наданого державного замовлення від випуску бак., денна'].value_counts()[:160]
# Out:
# 60.000000     203
# 100.000000    188
# 50.000000     169
# 40.000000     146
# 80.000000     127
# 66.666667      94
# 62.500000      52
# 57.142857      50
# 140.000000     47
# 55.555556      47
# 120.000000     43
# 71.428571      39
# 83.333333      34
# 75.000000      33
# 20.000000      29
# 54.545455      28
# 58.333333      26
# 200.000000     26
# 53.333333      25
# 33.333333      25
# 70.000000      23
# 58.823529      22
# 52.631579      22
# 61.538462      20
# 160.000000     20
# Name: % наданого державного замовлення від випуску бак., денна, dtype: int64

# %%
#spec=df[(df['Код спец.']==172)]
#spec.sort_values('Mult K1-K9', axis=0, ascending=False, inplace=False)

# %% [markdown]
# ### Може це все наші видумки. Давайте подивимося на залежність кількості виділених держбюджетних місць від значення добутку коефіцієнтів К1-К9. Очикуємо бачити на якусь залежність, зі збільшенням значення добутку К1-К9 повинні зростати обсяги держзамовлення. Що ми бачимо? Ми бачимо нормальний розподіл, як ми знаємо зі статистики, нормальним розподілом можна описувати случайні величини. Іншими словами немає взаємозв'язку між добутком К1-К9 та виділеним держбюджетом на магістра.

# %%
plt.figure(figsize=(10,7))
plt.title('Залежність обсягу державного замовлення від добутку коеф. К1,К2..К9')
plt.xlabel('Добуток коеф. К1,К2..К9')
plt.ylabel('Обсяг державного замовлення всього, денна')
plt.xlim(1,3)
plt.ylim(0,250)
plt.scatter(df['Mult K1-K9'], df['Обсяг державного замовлення Всього, денна'])
plt.show()

# %% [markdown]
# ### Ви будете заперечувати і скажете, що добуток К1-К9 не повинен напряму залежати від держбюджетних місць. Ок, згоден. Тоді давайте подивимося на наступне: на залежність 'відсоток наданого державного замовлення за ОС магістр від випуску бак., денна' від добутку коефіцієнтів К1-К9. Із логіки - з ростом значення добутку коефіцієнтів К1-К9 (університет якісний, спеціальність супер) повинен і зростати 'відсоток наданого державного замовлення за ОС магістр від випуску бак., денна' . Що ми бачимо? Ніякої залежності, можна отримати 100% від випуску бакалавра при значенні добутку К1-К9 рівними 1,1 та при 2,0 і вище. Крім того зверніть увагу на горизонтальні лінії з точок, як ми показували вище комісія МОН брала круглі цифри і це точно немає ніякого стосунку до коефіцієнтів.

# %%
plt.figure(figsize=(10,7))
plt.title('Залежність `% наданого державного замовлення від випуску бак.` від добутку коеф. К1,К2..К9')
plt.xlabel('Добуток коеф. К1,К2..К9')
plt.ylabel('% наданого державного замовлення від випуску бак., денна')
plt.xlim(1,3)
plt.ylim(0,250)
plt.scatter(df['Mult K1-K9'], df['% наданого державного замовлення від випуску бак., денна'])
plt.show()

# %% [markdown]
# ### Ок, давайте порахуємо кореляцію усьго чого можна, можливо ми щось знайдемо?
# ##### https://uk.wikipedia.org/wiki/%D0%9A%D0%BE%D0%B5%D1%84%D1%96%D1%86%D1%96%D1%94%D0%BD%D1%82_%D0%BA%D0%BE%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D1%96%D1%97_%D0%9F%D1%96%D1%80%D1%81%D0%BE%D0%BD%D0%B0

# %% [markdown]
# #### Що ми бачимо з таблиці? Незначну кореляцію добутку коефіцієнтів К1-К9 з обсягом державного замовлення за ОС магістр. Вплив окремих коефіцієнтів взагалі мізерний, що свідчить скоріш за все про не досконалу методику. Смішним є те, що обсяг державного замовлення за ОС магістр краще корелює з кодом спеціальності (це цікава річ) ніж з окремими коефіцієнтами. Єдине, що необхідно відмітити дуже гарну кореляцію - 0.92 обсягу державного замовлення за ОС магістр з обсягом випуску бакалаврів, но якщо б і цього не було тоді я не знаю)))

# %%
temp_corr=df.copy()

# %%
temp_corr.drop(['рік'], axis=1, inplace=True)

# %%
temp_corr.corr()
# Out:
#                                                      код ЗВО  Код спец.  \
# код ЗВО                                             1.000000  -0.028740
# Код спец.                                          -0.028740   1.000000
# Код. спеціал                                       -0.063076   0.456571
# K1                                                 -0.124625   0.114450
# K2                                                  0.011160   0.119172
# K3                                                 -0.042990  -0.026025
# K4                                                 -0.023732  -0.035922
# K5                                                  0.032719  -0.022733
# K6                                                 -0.027256  -0.005871
# K7                                                 -0.035889  -0.057950
# K8                                                  0.001006   0.084296
# K9                                                  0.047109  -0.158979
# Mult K1-K9                                         -0.069142  -0.039485
# Випуск бак., денна                                  0.021640   0.117287
# Випуск бак. min 5, денна                            0.021806   0.119519
# Конкурсний бал                                      0.009719   0.113518
# Обсяг державного замовлення ОПП, денна              0.019909   0.133057
# Обсяг державного замовлення ОНП, денна             -0.024005   0.042625
# Обсяг державного замовлення Всього, денна           0.010018   0.135637
# % наданого державного замовлення від випуску ба...  0.004249   0.060941
#
#                                                     Код. спеціал        K1  \
# код ЗВО                                                -0.063076 -0.124625
# Код спец.                                               0.456571  0.114450
# Код. спеціал                                            1.000000  0.110956
# K1                                                      0.110956  1.000000
# K2                                                      0.107295  0.187452
# K3                                                     -0.025796  0.580790
# K4                                                     -0.017942 -0.193321
# K5                                                     -0.026249  0.003176
# K6                                                      0.124281  0.114493
# K7                                                      0.066646 -0.182007
# K8                                                      0.059689  0.022346
# K9                                                     -0.116469 -0.053131
# Mult K1-K9                                              0.072398  0.462286
# Випуск бак., денна                                      0.062302  0.111500
# Випуск бак. min 5, денна                                0.064974  0.107499
# Конкурсний бал                                          0.073408  0.155532
# Обсяг державного замовлення ОПП, денна                  0.071101  0.109225
# Обсяг державного замовлення ОНП, денна                  0.045016  0.182567
# Обсяг державного замовлення Всього, денна               0.080002  0.161262
# % наданого державного замовлення від випуску ба...      0.011049  0.066011
#
#                                                           K2        K3  \
# код ЗВО                                             0.011160 -0.042990
# Код спец.                                           0.119172 -0.026025
# Код. спеціал                                        0.107295 -0.025796
# K1                                                  0.187452  0.580790
# K2                                                  1.000000  0.028713
# K3                                                  0.028713  1.000000
# K4                                                  0.009615 -0.076003
# K5                                                 -0.037330  0.009766
# K6                                                  0.050073  0.118032
# K7                                                 -0.044215 -0.071812
# K8                                                  0.060407 -0.002507
# K9                                                  0.001592 -0.053510
# Mult K1-K9                                          0.196813  0.454929
# Випуск бак., денна                                  0.029915  0.110830
# Випуск бак. min 5, денна                            0.029811  0.110743
# Конкурсний бал                                      0.043737  0.159612
# Обсяг державного замовлення ОПП, денна              0.101850  0.085896
# Обсяг державного замовлення ОНП, денна             -0.108769  0.249159
# Обсяг державного замовлення Всього, денна           0.055995  0.162534
# % наданого державного замовлення від випуску ба...  0.047297  0.090186
#
#                                                           K4        K5  \
# код ЗВО                                            -0.023732  0.032719
# Код спец.                                          -0.035922 -0.022733
# Код. спеціал                                       -0.017942 -0.026249
# K1                                                 -0.193321  0.003176
# K2                                                  0.009615 -0.037330
# K3                                                 -0.076003  0.009766
# K4                                                  1.000000  0.022472
# K5                                                  0.022472  1.000000
# K6                                                 -0.129652  0.131813
# K7                                                  0.150039  0.031501
# K8                                                 -0.031604  0.078448
# K9                                                 -0.024474 -0.014174
# Mult K1-K9                                          0.118876  0.251236
# Випуск бак., денна                                 -0.193414  0.136456
# Випуск бак. min 5, денна                           -0.188772  0.125454
# Конкурсний бал                                     -0.178515  0.130618
# Обсяг державного замовлення ОПП, денна             -0.151809  0.114663
# Обсяг державного замовлення ОНП, денна             -0.139384  0.036272
# Обсяг державного замовлення Всього, денна          -0.185450  0.116730
# % наданого державного замовлення від випуску ба... -0.036433 -0.115392
#
#                                                           K6        K7  \
# код ЗВО                                            -0.027256 -0.035889
# Код спец.                                          -0.005871 -0.057950
# Код. спеціал                                        0.124281  0.066646
# K1                                                  0.114493 -0.182007
# K2                                                  0.050073 -0.044215
# K3                                                  0.118032 -0.071812
# K4                                                 -0.129652  0.150039
# K5                                                  0.131813  0.031501
# K6                                                  1.000000  0.015642
# K7                                                  0.015642  1.000000
# K8                                                  0.082054  0.230201
# K9                                                 -0.041296  0.091180
# Mult K1-K9                                          0.352872  0.529023
# Випуск бак., денна                                  0.376540 -0.016695
# Випуск бак. min 5, денна                            0.375123 -0.012312
# Конкурсний бал                                      0.399283  0.028299
# Обсяг державного замовлення ОПП, денна              0.351905  0.002761
# Обсяг державного замовлення ОНП, денна              0.201028  0.007303
# Обсяг державного замовлення Всього, денна           0.388594  0.004986
# % наданого державного замовлення від випуску ба...  0.003280  0.033943
#
#                                                           K8        K9  \
# код ЗВО                                             0.001006  0.047109
# Код спец.                                           0.084296 -0.158979
# Код. спеціал                                        0.059689 -0.116469
# K1                                                  0.022346 -0.053131
# K2                                                  0.060407  0.001592
# K3                                                 -0.002507 -0.053510
# K4                                                 -0.031604 -0.024474
# K5                                                  0.078448 -0.014174
# K6                                                  0.082054 -0.041296
# K7                                                  0.230201  0.091180
# K8                                                  1.000000  0.156071
# K9                                                  0.156071  1.000000
# Mult K1-K9                                          0.345340  0.383789
# Випуск бак., денна                                  0.104706 -0.011802
# Випуск бак. min 5, денна                            0.103777 -0.013948
# Конкурсний бал                                      0.134371  0.012996
# Обсяг державного замовлення ОПП, денна              0.111273  0.014725
# Обсяг державного замовлення ОНП, денна              0.055166 -0.022067
# Обсяг державного замовлення Всього, денна           0.120033  0.005950
# % наданого державного замовлення від випуску ба... -0.007434  0.011870
#
#                                                     Mult K1-K9  \
# код ЗВО                                              -0.069142
# Код спец.                                            -0.039485
# Код. спеціал                                          0.072398
# K1                                                    0.462286
# K2                                                    0.196813
# K3                                                    0.454929
# K4                                                    0.118876
# K5                                                    0.251236
# K6                                                    0.352872
# K7                                                    0.529023
# K8                                                    0.345340
# K9                                                    0.383789
# Mult K1-K9                                            1.000000
# Випуск бак., денна                                    0.175271
# Випуск бак. min 5, денна                              0.173207
# Конкурсний бал                                        0.257301
# Обсяг державного замовлення ОПП, денна                0.198144
# Обсяг державного замовлення ОНП, денна                0.160078
# Обсяг державного замовлення Всього, денна             0.234662
# % наданого державного замовлення від випуску ба...    0.044265
#
#                                                     Випуск бак., денна  \
# код ЗВО                                                       0.021640
# Код спец.                                                     0.117287
# Код. спеціал                                                  0.062302
# K1                                                            0.111500
# K2                                                            0.029915
# K3                                                            0.110830
# K4                                                           -0.193414
# K5                                                            0.136456
# K6                                                            0.376540
# K7                                                           -0.016695
# K8                                                            0.104706
# K9                                                           -0.011802
# Mult K1-K9                                                    0.175271
# Випуск бак., денна                                            1.000000
# Випуск бак. min 5, денна                                      0.998887
# Конкурсний бал                                                0.988675
# Обсяг державного замовлення ОПП, денна                        0.890885
# Обсяг державного замовлення ОНП, денна                        0.308681
# Обсяг державного замовлення Всього, денна                     0.916033
# % наданого державного замовлення від випуску ба...           -0.173869
#
#                                                     Випуск бак. min 5, денна  \
# код ЗВО                                                             0.021806
# Код спец.                                                           0.119519
# Код. спеціал                                                        0.064974
# K1                                                                  0.107499
# K2                                                                  0.029811
# K3                                                                  0.110743
# K4                                                                 -0.188772
# K5                                                                  0.125454
# K6                                                                  0.375123
# K7                                                                 -0.012312
# K8                                                                  0.103777
# K9                                                                 -0.013948
# Mult K1-K9                                                          0.173207
# Випуск бак., денна                                                  0.998887
# Випуск бак. min 5, денна                                            1.000000
# Конкурсний бал                                                      0.990159
# Обсяг державного замовлення ОПП, денна                              0.892539
# Обсяг державного замовлення ОНП, денна                              0.309424
# Обсяг державного замовлення Всього, денна                           0.917792
# % наданого державного замовлення від випуску ба...                 -0.161317
#
#                                                     Конкурсний бал  \
# код ЗВО                                                   0.009719
# Код спец.                                                 0.113518
# Код. спеціал                                              0.073408
# K1                                                        0.155532
# K2                                                        0.043737
# K3                                                        0.159612
# K4                                                       -0.178515
# K5                                                        0.130618
# K6                                                        0.399283
# K7                                                        0.028299
# K8                                                        0.134371
# K9                                                        0.012996
# Mult K1-K9                                                0.257301
# Випуск бак., денна                                        0.988675
# Випуск бак. min 5, денна                                  0.990159
# Конкурсний бал                                            1.000000
# Обсяг державного замовлення ОПП, денна                    0.896643
# Обсяг державного замовлення ОНП, денна                    0.330583
# Обсяг державного замовлення Всього, денна                 0.928688
# % наданого державного замовлення від випуску ба...       -0.145595
#
#                                                     Обсяг державного замовлення ОПП, денна  \
# код ЗВО                                                                           0.019909
# Код спец.                                                                         0.133057
# Код. спеціал                                                                      0.071101
# K1                                                                                0.109225
# K2                                                                                0.101850
# K3                                                                                0.085896
# K4                                                                               -0.151809
# K5                                                                                0.114663
# K6                                                                                0.351905
# K7                                                                                0.002761
# K8                                                                                0.111273
# K9                                                                                0.014725
# Mult K1-K9                                                                        0.198144
# Випуск бак., денна                                                                0.890885
# Випуск бак. min 5, денна                                                          0.892539
# Конкурсний бал                                                                    0.896643
# Обсяг державного замовлення ОПП, денна                                            1.000000
# Обсяг державного замовлення ОНП, денна                                            0.090232
# Обсяг державного замовлення Всього, денна                                         0.941547
# % наданого державного замовлення від випуску ба...                                0.038760
#
#                                                     Обсяг державного замовлення ОНП, денна  \
# код ЗВО                                                                          -0.024005
# Код спец.                                                                         0.042625
# Код. спеціал                                                                      0.045016
# K1                                                                                0.182567
# K2                                                                               -0.108769
# K3                                                                                0.249159
# K4                                                                               -0.139384
# K5                                                                                0.036272
# K6                                                                                0.201028
# K7                                                                                0.007303
# K8                                                                                0.055166
# K9                                                                               -0.022067
# Mult K1-K9                                                                        0.160078
# Випуск бак., денна                                                                0.308681
# Випуск бак. min 5, денна                                                          0.309424
# Конкурсний бал                                                                    0.330583
# Обсяг державного замовлення ОПП, денна                                            0.090232
# Обсяг державного замовлення ОНП, денна                                            1.000000
# Обсяг державного замовлення Всього, денна                                         0.420465
# % наданого державного замовлення від випуску ба...                                0.097194
#
#                                                     Обсяг державного замовлення Всього, денна  \
# код ЗВО                                                                              0.010018
# Код спец.                                                                            0.135637
# Код. спеціал                                                                         0.080002
# K1                                                                                   0.161262
# K2                                                                                   0.055995
# K3                                                                                   0.162534
# K4                                                                                  -0.185450
# K5                                                                                   0.116730
# K6                                                                                   0.388594
# K7                                                                                   0.004986
# K8                                                                                   0.120033
# K9                                                                                   0.005950
# Mult K1-K9                                                                           0.234662
# Випуск бак., денна                                                                   0.916033
# Випуск бак. min 5, денна                                                             0.917792
# Конкурсний бал                                                                       0.928688
# Обсяг державного замовлення ОПП, денна                                               0.941547
# Обсяг державного замовлення ОНП, денна                                               0.420465
# Обсяг державного замовлення Всього, денна                                            1.000000
# % наданого державного замовлення від випуску ба...                                   0.068188
#
#                                                     % наданого державного замовлення від випуску бак., денна
# код ЗВО                                                                                      0.004249
# Код спец.                                                                                    0.060941
# Код. спеціал                                                                                 0.011049
# K1                                                                                           0.066011
# K2                                                                                           0.047297
# K3                                                                                           0.090186
# K4                                                                                          -0.036433
# K5                                                                                          -0.115392
# K6                                                                                           0.003280
# K7                                                                                           0.033943
# K8                                                                                          -0.007434
# K9                                                                                           0.011870
# Mult K1-K9                                                                                   0.044265
# Випуск бак., денна                                                                          -0.173869
# Випуск бак. min 5, денна                                                                    -0.161317
# Конкурсний бал                                                                              -0.145595
# Обсяг державного замовлення ОПП, денна                                                       0.038760
# Обсяг державного замовлення ОНП, денна                                                       0.097194
# Обсяг державного замовлення Всього, денна                                                    0.068188
# % наданого державного замовлення від випуску ба...                                           1.000000

# %% [markdown]
# ### Ще порція статистичної інформації. Зверніть увагу на значення коефіцієнтів, наприклад К3, К5 взагалі слабо змінюються. Зверніть увагу на статистику по випуску в по місцям

# %%
columns=['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'K7', 'K8', 'K9',
       'Mult K1-K9', 'Випуск бак., денна', 'Випуск бак. min 5, денна',
       'Конкурсний бал', 'Обсяг державного замовлення ОПП, денна',
       'Обсяг державного замовлення ОНП, денна',
       'Обсяг державного замовлення Всього, денна',
       '% наданого державного замовлення від випуску бак., денна']

# %%
df[columns].describe()
# Out:
#                 K1           K2           K3           K4           K5  \
# count  3014.000000  3014.000000  3014.000000  3014.000000  3014.000000
# mean      1.072873     1.059672     1.010086     1.028494     1.091971
# std       0.059720     0.017648     0.030120     0.025837     0.027179
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.030000     1.040000     1.000000     1.020000     1.100000
# 50%       1.060000     1.070000     1.000000     1.020000     1.100000
# 75%       1.100000     1.070000     1.000000     1.040000     1.100000
# max       1.270000     1.070000     1.100000     1.100000     1.100000
#
#                 K6           K7           K8           K9   Mult K1-K9  \
# count  3014.000000  3014.000000  3014.000000  3014.000000  3014.000000
# mean      1.030640     1.101493     1.013106     1.008630     1.498204
# std       0.035806     0.081846     0.032557     0.059584     0.199000
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     1.012500     1.000000     1.000000     1.361756
# 50%       1.000000     1.100000     1.000000     1.000000     1.480158
# 75%       1.050000     1.200000     1.010000     1.000000     1.600996
# max       1.100000     1.200000     1.100000     2.000000     2.871203
#
#        Випуск бак., денна  Випуск бак. min 5, денна  Конкурсний бал  \
# count         3014.000000               3014.000000     3014.000000
# mean            25.024884                 25.787658       39.823335
# std             34.981950                 34.483030       56.160513
# min              0.000000                  5.000000        0.000000
# 25%              6.000000                  6.000000        9.638947
# 50%             15.000000                 15.000000       21.927468
# 75%             29.000000                 29.000000       43.992141
# max            425.000000                425.000000      635.755962
#
#        Обсяг державного замовлення ОПП, денна  \
# count                             3014.000000
# mean                                14.094559
# std                                 17.911851
# min                                  0.000000
# 25%                                  5.000000
# 50%                                  9.000000
# 75%                                 16.000000
# max                                234.000000
#
#        Обсяг державного замовлення ОНП, денна  \
# count                             3014.000000
# mean                                 1.349370
# std                                  6.650617
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                147.000000
#
#        Обсяг державного замовлення Всього, денна  \
# count                                3014.000000
# mean                                   15.443928
# std                                    19.661203
# min                                     0.000000
# 25%                                     5.000000
# 50%                                    10.000000
# 75%                                    17.000000
# max                                   234.000000
#
#        % наданого державного замовлення від випуску бак., денна
# count                                        3014.000000
# mean                                           70.642857
# std                                            49.870133
# min                                             0.000000
# 25%                                            50.000000
# 50%                                            60.000000
# 75%                                            80.000000
# max                                          1000.000000

# %% [markdown]
# ### І на останок порція графіків залежності параметрів: 'Mult K1-K9', 'Випуск бак. min 5, денна', 'Обсяг державного замовлення Всього, денна', '% наданого державного замовлення від випуску бак., денна'. Що можна сказати, при розподілі держбюджетних місць за ОС магістр комісія МОН опиралася тільки на один показник - 'Випуск бакалаврів'

# %%
columns=['Mult K1-K9', 'Випуск бак. min 5, денна',
        'Обсяг державного замовлення Всього, денна',
       '% наданого державного замовлення від випуску бак., денна']

# %%
sns.pairplot(df[columns], size=4.0)
